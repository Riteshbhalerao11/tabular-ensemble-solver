# %%
import os
import joblib
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import logging
from pathlib import Path
import joblib
import json

from scipy.stats import gaussian_kde
from optuna.samplers import TPESampler

from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    KFold,
    GridSearchCV
)
from sklearn.metrics import (
    make_scorer,
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error
)

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.linear_model import RidgeCV, ElasticNetCV, LassoCV
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (
    RBF,
    Matern,
    RationalQuadratic,
    ConstantKernel as C
)


# # Load data
# X = pd.read_csv("/pscratch/sd/r/ritesh11/temp_dir/dataset/train/BlendProperty6_X.csv")
# y = pd.read_csv("/pscratch/sd/r/ritesh11/temp_dir/dataset/train/BlendProperty6_y.csv")
# X_val = pd.read_csv("/pscratch/sd/r/ritesh11/temp_dir/dataset/val/BlendProperty6_X.csv")
# y_val = pd.read_csv("/pscratch/sd/r/ritesh11/temp_dir/dataset/val/BlendProperty6_y.csv")
# test_df = pd.read_csv("/pscratch/sd/r/ritesh11/temp_dir/dataset/test.csv")

# %%
def get_model_scores(model, X, y, model_name):
    """
    Returns CV scores and trained model
    """
    model.fit(X, y)
    y_pred = model.predict(X)
    
    return {
        'name': model_name,
        'model': model,
        'MAPE': mean_absolute_percentage_error(y, y_pred),
        'MAE': mean_absolute_error(y, y_pred),
        'RMSE': np.sqrt(mean_squared_error(y, y_pred))
    }

# %%
def evaluate_model(model, X_val, y_val):
    y_pred = model.predict(X_val)
    return {
        "MAPE": mean_absolute_percentage_error(y_val, y_pred),
        "MAE": mean_absolute_error(y_val, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_val, y_pred))
    }

# %%
# ========== Logging Setup ==========
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[logging.StreamHandler()]
)

# ========== Config ==========
degree = 2
cv = 5
targets = [f"BlendProperty{i}" for i in range(1, 11)]

# %%
BASE_PATH = "/pscratch/sd/r/ritesh11/temp_dir/dataset"
SAVE_PATH = "/pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs"
Path(SAVE_PATH).mkdir(parents=True, exist_ok=True)

# %%
# ========== Main Loop ==========
for t in targets:
    logging.info(f"🔧 Processing target: {t}")

    # ========== Load Data ==========
    X = pd.read_csv(f"{BASE_PATH}/train/{t}_X.csv")
    y = pd.read_csv(f"{BASE_PATH}/train/{t}_y.csv").values.ravel()
    X_val = pd.read_csv(f"{BASE_PATH}/val/{t}_X.csv")
    y_val = pd.read_csv(f"{BASE_PATH}/val/{t}_y.csv").values.ravel()

    # ========== Build Models ==========
    models = {
        "LASSOCV": make_pipeline(
            StandardScaler(),
            PolynomialFeatures(degree),
            LassoCV(cv=cv, n_jobs=-1)
        ),
        "RIDGECV": make_pipeline(
            StandardScaler(),
            PolynomialFeatures(degree),
            RidgeCV(alphas=np.logspace(-6, 6, 13), cv=cv)
        ),
        "ELASTICNETCV": make_pipeline(
            StandardScaler(),
            PolynomialFeatures(degree),
            ElasticNetCV(cv=cv, l1_ratio=[0.1, 0.5, 0.9], n_jobs=-1)
        )
    }

    results = {}

    for name, model in models.items():
        logging.info(f"🧠 Training model: {name} for {t}")
        model.fit(X, y)

        # Save model
        model_path = f"{SAVE_PATH}/{t}_{name}.joblib"
        joblib.dump(model, model_path)
        logging.info(f"💾 Saved model to {model_path}")

        # Save optimal hyperparameters
        if hasattr(model.named_steps[name.lower()], 'alpha_'):
            alpha = model.named_steps[name.lower()].alpha_
        elif name == "ELASTICNETCV":
            alpha = {
                "alpha": model.named_steps[name.lower()].alpha_,
                "l1_ratio": model.named_steps[name.lower()].l1_ratio_
            }
        else:
            alpha = "N/A"

        param_path = f"{SAVE_PATH}/{t}_{name}_params.json"
        with open(param_path, "w") as f:
            json.dump({"alpha": alpha}, f, indent=2)
        logging.info(f"📄 Saved params to {param_path}")

        # Evaluate on holdout
        metrics = evaluate_model(model, X_val, y_val)
        results[name] = metrics
        logging.info(f"✅ {name} hold-out metrics: {metrics}")

    # Save results
    results_df = pd.DataFrame(results).T
    results_df.to_csv(f"{SAVE_PATH}/{t}_metrics.csv")
    logging.info(f"📊 Metrics saved to {SAVE_PATH}/{t}_metrics.csv\n")
# Out:
# 2025-07-08 09:15:47,515 [INFO] 🔧 Processing target: BlendProperty1
# 2025-07-08 09:15:47,560 [INFO] 🧠 Training model: LASSOCV for BlendProperty1
# 2025-07-08 09:16:00,813 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty1_LASSOCV.joblib
# 2025-07-08 09:16:00,825 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty1_LASSOCV_params.json
# 2025-07-08 09:16:00,833 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 0.03038513487929343, 'MAE': 0.002435146165653691, 'RMSE': np.float64(0.002990723298540005)}
# 2025-07-08 09:16:00,834 [INFO] 🧠 Training model: RIDGECV for BlendProperty1
# 2025-07-08 09:16:23,414 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty1_RIDGECV.joblib
# 2025-07-08 09:16:23,419 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty1_RIDGECV_params.json
# 2025-07-08 09:16:23,424 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 0.0011051240392759604, 'MAE': 6.762793006113837e-05, 'RMSE': np.float64(8.492560463082593e-05)}
# 2025-07-08 09:16:23,424 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty1
# 2025-07-08 09:16:48,550 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty1_ELASTICNETCV.joblib
# 2025-07-08 09:16:48,554 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty1_ELASTICNETCV_params.json
# 2025-07-08 09:16:48,619 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 0.030185102511425987, 'MAE': 0.0025365244979262107, 'RMSE': np.float64(0.003114943484986465)}
# 2025-07-08 09:16:48,643 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty1_metrics.csv
#
# 2025-07-08 09:16:48,644 [INFO] 🔧 Processing target: BlendProperty2
# 2025-07-08 09:16:48,753 [INFO] 🧠 Training model: LASSOCV for BlendProperty2
# 2025-07-08 09:16:57,219 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty2_LASSOCV.joblib
# 2025-07-08 09:16:57,225 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty2_LASSOCV_params.json
# 2025-07-08 09:16:57,230 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 0.7473034785459695, 'MAE': 0.014591984051231027, 'RMSE': np.float64(0.021235472903881617)}
# 2025-07-08 09:16:57,231 [INFO] 🧠 Training model: RIDGECV for BlendProperty2
# 2025-07-08 09:17:15,569 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty2_RIDGECV.joblib
# 2025-07-08 09:17:15,573 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty2_RIDGECV_params.json
# 2025-07-08 09:17:15,616 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 0.7665145591282995, 'MAE': 0.03372827480088269, 'RMSE': np.float64(0.04277041712841538)}
# 2025-07-08 09:17:15,617 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty2
# 2025-07-08 09:17:25,248 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty2_ELASTICNETCV.joblib
# 2025-07-08 09:17:25,256 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty2_ELASTICNETCV_params.json
# 2025-07-08 09:17:25,261 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 0.7478498016285302, 'MAE': 0.01460502704607427, 'RMSE': np.float64(0.021299759946822604)}
# 2025-07-08 09:17:25,269 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty2_metrics.csv
#
# 2025-07-08 09:17:25,269 [INFO] 🔧 Processing target: BlendProperty3
# 2025-07-08 09:17:25,309 [INFO] 🧠 Training model: LASSOCV for BlendProperty3
# 2025-07-08 09:17:28,463 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty3_LASSOCV.joblib
# 2025-07-08 09:17:28,466 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty3_LASSOCV_params.json
# 2025-07-08 09:17:28,470 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 1.737813200462571, 'MAE': 0.13856610092256852, 'RMSE': np.float64(0.1814895850793569)}
# 2025-07-08 09:17:28,470 [INFO] 🧠 Training model: RIDGECV for BlendProperty3
# 2025-07-08 09:17:37,983 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty3_RIDGECV.joblib
# 2025-07-08 09:17:37,986 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty3_RIDGECV_params.json
# 2025-07-08 09:17:37,991 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 1.7396901683770962, 'MAE': 0.25894833014889396, 'RMSE': np.float64(0.3193221921022438)}
# 2025-07-08 09:17:37,991 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty3
# 2025-07-08 09:17:49,520 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty3_ELASTICNETCV.joblib
# 2025-07-08 09:17:49,523 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty3_ELASTICNETCV_params.json
# 2025-07-08 09:17:49,528 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 1.7353025562978415, 'MAE': 0.13864239019388247, 'RMSE': np.float64(0.1816056611185327)}
# 2025-07-08 09:17:49,532 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty3_metrics.csv
#
# 2025-07-08 09:17:49,532 [INFO] 🔧 Processing target: BlendProperty4
# 2025-07-08 09:17:49,564 [INFO] 🧠 Training model: LASSOCV for BlendProperty4
# 2025-07-08 09:17:57,738 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty4_LASSOCV.joblib
# 2025-07-08 09:17:57,814 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty4_LASSOCV_params.json
# 2025-07-08 09:17:57,820 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 0.1395350727914129, 'MAE': 0.023353902832159937, 'RMSE': np.float64(0.03338544754026036)}
# 2025-07-08 09:17:57,821 [INFO] 🧠 Training model: RIDGECV for BlendProperty4
# 2025-07-08 09:18:25,891 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty4_RIDGECV.joblib
# 2025-07-08 09:18:25,895 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty4_RIDGECV_params.json
# 2025-07-08 09:18:25,900 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 0.34753984307111785, 'MAE': 0.046564263928173165, 'RMSE': np.float64(0.058815002006791774)}
# 2025-07-08 09:18:25,900 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty4
# 2025-07-08 09:18:34,209 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty4_ELASTICNETCV.joblib
# 2025-07-08 09:18:34,213 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty4_ELASTICNETCV_params.json
# 2025-07-08 09:18:34,218 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 0.1393114964958786, 'MAE': 0.023359435105590867, 'RMSE': np.float64(0.03339865379597202)}
# 2025-07-08 09:18:34,222 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty4_metrics.csv
#
# 2025-07-08 09:18:34,224 [INFO] 🔧 Processing target: BlendProperty5
# 2025-07-08 09:18:34,268 [INFO] 🧠 Training model: LASSOCV for BlendProperty5
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.860e-01, tolerance: 1.459e-01
#   model = cd_fast.enet_coordinate_descent(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.384e-01, tolerance: 1.459e-01
#   model = cd_fast.enet_coordinate_descent(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.437e-01, tolerance: 1.459e-01
#   model = cd_fast.enet_coordinate_descent(
# 2025-07-08 09:18:58,063 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty5_LASSOCV.joblib
# 2025-07-08 09:18:58,066 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty5_LASSOCV_params.json
# 2025-07-08 09:18:58,071 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 1.2398630318071413, 'MAE': 0.5033965958971547, 'RMSE': np.float64(0.6610638456468702)}
# 2025-07-08 09:18:58,071 [INFO] 🧠 Training model: RIDGECV for BlendProperty5
# 2025-07-08 09:19:05,771 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty5_RIDGECV.joblib
# 2025-07-08 09:19:05,774 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty5_RIDGECV_params.json
# 2025-07-08 09:19:05,778 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 1.2654075431586747, 'MAE': 0.6123967215759132, 'RMSE': np.float64(0.8625954926523842)}
# 2025-07-08 09:19:05,778 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty5
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.971e-01, tolerance: 1.459e-01
#   model = cd_fast.enet_coordinate_descent(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.626e-01, tolerance: 1.459e-01
#   model = cd_fast.enet_coordinate_descent(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.219e-01, tolerance: 1.459e-01
#   model = cd_fast.enet_coordinate_descent(
# 2025-07-08 09:20:42,316 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty5_ELASTICNETCV.joblib
# 2025-07-08 09:20:42,319 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty5_ELASTICNETCV_params.json
# 2025-07-08 09:20:42,323 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 1.2329938366413626, 'MAE': 0.5030857737420709, 'RMSE': np.float64(0.6614517654853794)}
# 2025-07-08 09:20:42,327 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty5_metrics.csv
#
# 2025-07-08 09:20:42,327 [INFO] 🔧 Processing target: BlendProperty6
# 2025-07-08 09:20:42,365 [INFO] 🧠 Training model: LASSOCV for BlendProperty6
# 2025-07-08 09:20:44,143 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty6_LASSOCV.joblib
# 2025-07-08 09:20:44,147 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty6_LASSOCV_params.json
# 2025-07-08 09:20:44,152 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 0.006178640092370085, 'MAE': 0.0020897090619020177, 'RMSE': np.float64(0.0026039710103034986)}
# 2025-07-08 09:20:44,152 [INFO] 🧠 Training model: RIDGECV for BlendProperty6
# 2025-07-08 09:21:09,938 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty6_RIDGECV.joblib
# 2025-07-08 09:21:09,942 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty6_RIDGECV_params.json
# 2025-07-08 09:21:09,947 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 0.0003623836751279713, 'MAE': 7.934174806525157e-05, 'RMSE': np.float64(9.787195704110031e-05)}
# 2025-07-08 09:21:09,947 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty6
# 2025-07-08 09:21:26,614 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty6_ELASTICNETCV.joblib
# 2025-07-08 09:21:26,617 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty6_ELASTICNETCV_params.json
# 2025-07-08 09:21:26,623 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 0.006326023824194786, 'MAE': 0.0021639455950168114, 'RMSE': np.float64(0.0026897163627396547)}
# 2025-07-08 09:21:26,628 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty6_metrics.csv
#
# 2025-07-08 09:21:26,628 [INFO] 🔧 Processing target: BlendProperty7
# 2025-07-08 09:21:26,719 [INFO] 🧠 Training model: LASSOCV for BlendProperty7
# 2025-07-08 09:21:39,120 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty7_LASSOCV.joblib
# 2025-07-08 09:21:39,124 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty7_LASSOCV_params.json
# 2025-07-08 09:21:39,130 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 0.9248338497213402, 'MAE': 0.13471579957642732, 'RMSE': np.float64(0.171124481135857)}
# 2025-07-08 09:21:39,131 [INFO] 🧠 Training model: RIDGECV for BlendProperty7
# 2025-07-08 09:22:05,537 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty7_RIDGECV.joblib
# 2025-07-08 09:22:05,540 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty7_RIDGECV_params.json
# 2025-07-08 09:22:05,616 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 0.9993134157781348, 'MAE': 0.2552302851244612, 'RMSE': np.float64(0.3216555251168328)}
# 2025-07-08 09:22:05,616 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty7
# 2025-07-08 09:22:45,122 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty7_ELASTICNETCV.joblib
# 2025-07-08 09:22:45,125 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty7_ELASTICNETCV_params.json
# 2025-07-08 09:22:45,131 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 0.9239949048682793, 'MAE': 0.1348883380617267, 'RMSE': np.float64(0.17134548947682465)}
# 2025-07-08 09:22:45,134 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty7_metrics.csv
#
# 2025-07-08 09:22:45,135 [INFO] 🔧 Processing target: BlendProperty8
# 2025-07-08 09:22:45,319 [INFO] 🧠 Training model: LASSOCV for BlendProperty8
# 2025-07-08 09:22:55,443 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty8_LASSOCV.joblib
# 2025-07-08 09:22:55,516 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty8_LASSOCV_params.json
# 2025-07-08 09:22:55,522 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 0.2317918704858287, 'MAE': 0.07728660421610202, 'RMSE': np.float64(0.10351290219961068)}
# 2025-07-08 09:22:55,522 [INFO] 🧠 Training model: RIDGECV for BlendProperty8
# 2025-07-08 09:23:27,424 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty8_RIDGECV.joblib
# 2025-07-08 09:23:27,433 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty8_RIDGECV_params.json
# 2025-07-08 09:23:27,439 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 0.3965911162596435, 'MAE': 0.15630063757612078, 'RMSE': np.float64(0.19913750792132423)}
# 2025-07-08 09:23:27,440 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty8
# 2025-07-08 09:24:04,535 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty8_ELASTICNETCV.joblib
# 2025-07-08 09:24:04,538 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty8_ELASTICNETCV_params.json
# 2025-07-08 09:24:04,616 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 0.2323481192541508, 'MAE': 0.07741431203935173, 'RMSE': np.float64(0.10360923337716575)}
# 2025-07-08 09:24:04,621 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty8_metrics.csv
#
# 2025-07-08 09:24:04,622 [INFO] 🔧 Processing target: BlendProperty9
# 2025-07-08 09:24:04,722 [INFO] 🧠 Training model: LASSOCV for BlendProperty9
# 2025-07-08 09:24:26,547 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty9_LASSOCV.joblib
# 2025-07-08 09:24:26,550 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty9_LASSOCV_params.json
# 2025-07-08 09:24:26,617 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 0.5201448779085507, 'MAE': 0.16133105536323214, 'RMSE': np.float64(0.21541112214881533)}
# 2025-07-08 09:24:26,617 [INFO] 🧠 Training model: RIDGECV for BlendProperty9
# 2025-07-08 09:24:40,531 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty9_RIDGECV.joblib
# 2025-07-08 09:24:40,534 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty9_RIDGECV_params.json
# 2025-07-08 09:24:40,539 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 1.105946513105947, 'MAE': 0.3077994952549769, 'RMSE': np.float64(0.3875443969992359)}
# 2025-07-08 09:24:40,539 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty9
# 2025-07-08 09:24:57,526 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty9_ELASTICNETCV.joblib
# 2025-07-08 09:24:57,530 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty9_ELASTICNETCV_params.json
# 2025-07-08 09:24:57,536 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 0.51907249518293, 'MAE': 0.1614217974478655, 'RMSE': np.float64(0.2155531214196387)}
# 2025-07-08 09:24:57,541 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty9_metrics.csv
#
# 2025-07-08 09:24:57,613 [INFO] 🔧 Processing target: BlendProperty10
# 2025-07-08 09:24:57,741 [INFO] 🧠 Training model: LASSOCV for BlendProperty10
# 2025-07-08 09:25:05,486 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty10_LASSOCV.joblib
# 2025-07-08 09:25:05,489 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty10_LASSOCV_params.json
# 2025-07-08 09:25:05,495 [INFO] ✅ LASSOCV hold-out metrics: {'MAPE': 0.09695343906489767, 'MAE': 0.007951790314738225, 'RMSE': np.float64(0.01040568926932682)}
# 2025-07-08 09:25:05,495 [INFO] 🧠 Training model: RIDGECV for BlendProperty10
# 2025-07-08 09:25:14,252 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty10_RIDGECV.joblib
# 2025-07-08 09:25:14,257 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty10_RIDGECV_params.json
# 2025-07-08 09:25:14,266 [INFO] ✅ RIDGECV hold-out metrics: {'MAPE': 0.18289210976185172, 'MAE': 0.01287382199388177, 'RMSE': np.float64(0.016519776020503144)}
# 2025-07-08 09:25:14,267 [INFO] 🧠 Training model: ELASTICNETCV for BlendProperty10
# 2025-07-08 09:25:40,613 [INFO] 💾 Saved model to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty10_ELASTICNETCV.joblib
# 2025-07-08 09:25:40,617 [INFO] 📄 Saved params to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty10_ELASTICNETCV_params.json
# 2025-07-08 09:25:40,624 [INFO] ✅ ELASTICNETCV hold-out metrics: {'MAPE': 0.09670067622134722, 'MAE': 0.008002975016374751, 'RMSE': np.float64(0.010453798589583303)}
# 2025-07-08 09:25:40,628 [INFO] 📊 Metrics saved to /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/BlendProperty10_metrics.csv

# %%
# === Config ===
SAVE_PATH = "/pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs"
BASE_PATH = "/pscratch/sd/r/ritesh11/temp_dir/dataset"
ENSEMBLE_DIR = os.path.join(SAVE_PATH, "optuna_ensemble")
Path(ENSEMBLE_DIR).mkdir(parents=True, exist_ok=True)

MODEL_NAMES = ["LASSOCV", "RIDGECV", "ELASTICNETCV"]
TARGETS = [f"BlendProperty{i}" for i in range(1, 11)]

# %%
# === Loop over all targets ===
for TARGET in TARGETS:
    print(f"\n🔧 Optimizing ensemble weights for: {TARGET}")

    # === Load validation data ===
    X_val = pd.read_csv(f"{BASE_PATH}/val/{TARGET}_X.csv")
    y_val = pd.read_csv(f"{BASE_PATH}/val/{TARGET}_y.csv").values.ravel()

    # === Load predictions from all models ===
    preds = {}
    for name in MODEL_NAMES:
        model_path = os.path.join(SAVE_PATH, f"{TARGET}_{name}.joblib")
        model = joblib.load(model_path)
        preds[name] = model.predict(X_val)

    # === Define objective function ===
    def objective(trial):
        w1 = trial.suggest_float("w1", 0.0, 1.0)
        w2 = trial.suggest_float("w2", 0.0, 1.0)
        w3 = 1.0 - w1 - w2
        if w3 < 0:
            raise optuna.TrialPruned()

        y_pred = (
            w1 * preds["LASSOCV"] +
            w2 * preds["RIDGECV"] +
            w3 * preds["ELASTICNETCV"]
        )

        return mean_absolute_percentage_error(y_val, y_pred)
        

    # === Custom callback for logging every 100 trials ===
    def log_callback(study, trial):
        if trial.number % 100 == 0 and trial.value is not None:
            print(f"📈 {TARGET} | Trial {trial.number}: MAPE = {trial.value:.4f}")
        
    optuna.logging.set_verbosity(optuna.logging.WARNING)

    # === Run Optuna study ===
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=1000, callbacks=[log_callback])

    # === Save best weights ===
    best_weights = study.best_params
    best_weights["w3"] = 1.0 - best_weights["w1"] - best_weights["w2"]
    weights_path = os.path.join(ENSEMBLE_DIR, f"{TARGET}_weights.json")
    with open(weights_path, "w") as f:
        json.dump(best_weights, f, indent=2)

    print(f"✅ {TARGET} best weights: {best_weights}")
    print(f"📉 Best MAPE: {study.best_value:.4f}")
# Out:
# 🔧 Optimizing ensemble weights for: BlendProperty1
# 📈 BlendProperty1 | Trial 0: MAPE = 0.0216
# 📈 BlendProperty1 | Trial 200: MAPE = 0.0008
# 📈 BlendProperty1 | Trial 300: MAPE = 0.0006
# 📈 BlendProperty1 | Trial 400: MAPE = 0.0010
# 📈 BlendProperty1 | Trial 600: MAPE = 0.0024
# 📈 BlendProperty1 | Trial 700: MAPE = 0.0015
# ✅ BlendProperty1 best weights: {'w1': 0.000557166553044104, 'w2': 0.968124894937447, 'w3': 0.031317938509508925}
# 📉 Best MAPE: 0.0003
#
# 🔧 Optimizing ensemble weights for: BlendProperty2
# 📈 BlendProperty2 | Trial 0: MAPE = 0.7440
# 📈 BlendProperty2 | Trial 100: MAPE = 0.7427
# 📈 BlendProperty2 | Trial 200: MAPE = 0.7426
# 📈 BlendProperty2 | Trial 300: MAPE = 0.7426
# 📈 BlendProperty2 | Trial 400: MAPE = 0.7427
# 📈 BlendProperty2 | Trial 700: MAPE = 0.7428
# 📈 BlendProperty2 | Trial 800: MAPE = 0.7427
# ✅ BlendProperty2 best weights: {'w1': 0.7601189916387876, 'w2': 0.23701573838588397, 'w3': 0.0028652699753284327}
# 📉 Best MAPE: 0.7424
#
# 🔧 Optimizing ensemble weights for: BlendProperty3
# 📈 BlendProperty3 | Trial 0: MAPE = 1.4610
# 📈 BlendProperty3 | Trial 100: MAPE = 1.4607
# 📈 BlendProperty3 | Trial 300: MAPE = 1.4619
# 📈 BlendProperty3 | Trial 400: MAPE = 1.4576
# 📈 BlendProperty3 | Trial 500: MAPE = 1.4720
# 📈 BlendProperty3 | Trial 600: MAPE = 1.4560
# 📈 BlendProperty3 | Trial 700: MAPE = 1.4593
# 📈 BlendProperty3 | Trial 800: MAPE = 1.5016
# ✅ BlendProperty3 best weights: {'w1': 0.5859548706403265, 'w2': 0.3724877030754259, 'w3': 0.041557426284247634}
# 📉 Best MAPE: 1.4533
#
# 🔧 Optimizing ensemble weights for: BlendProperty4
# 📈 BlendProperty4 | Trial 0: MAPE = 0.1586
# 📈 BlendProperty4 | Trial 100: MAPE = 0.2130
# 📈 BlendProperty4 | Trial 200: MAPE = 0.1439
# 📈 BlendProperty4 | Trial 300: MAPE = 0.1438
# 📈 BlendProperty4 | Trial 400: MAPE = 0.1393
# 📈 BlendProperty4 | Trial 500: MAPE = 0.1452
# 📈 BlendProperty4 | Trial 600: MAPE = 0.1444
# 📈 BlendProperty4 | Trial 700: MAPE = 0.1399
# 📈 BlendProperty4 | Trial 800: MAPE = 0.1401
# 📈 BlendProperty4 | Trial 900: MAPE = 0.1437
# ✅ BlendProperty4 best weights: {'w1': 0.00022644006054396172, 'w2': 5.221772487109562e-05, 'w3': 0.999721342214585}
# 📉 Best MAPE: 0.1393
#
# 🔧 Optimizing ensemble weights for: BlendProperty5
# 📈 BlendProperty5 | Trial 200: MAPE = 1.0627
# 📈 BlendProperty5 | Trial 300: MAPE = 1.0688
# 📈 BlendProperty5 | Trial 400: MAPE = 1.0605
# 📈 BlendProperty5 | Trial 500: MAPE = 1.0805
# 📈 BlendProperty5 | Trial 600: MAPE = 1.0605
# 📈 BlendProperty5 | Trial 700: MAPE = 1.0615
# 📈 BlendProperty5 | Trial 800: MAPE = 1.0628
# 📈 BlendProperty5 | Trial 900: MAPE = 1.0794
# ✅ BlendProperty5 best weights: {'w1': 0.0001136653114342627, 'w2': 0.47001743554676817, 'w3': 0.5298688991417975}
# 📉 Best MAPE: 1.0584
#
# 🔧 Optimizing ensemble weights for: BlendProperty6
# 📈 BlendProperty6 | Trial 100: MAPE = 0.0004
# 📈 BlendProperty6 | Trial 200: MAPE = 0.0005
# 📈 BlendProperty6 | Trial 300: MAPE = 0.0003
# 📈 BlendProperty6 | Trial 400: MAPE = 0.0018
# ✅ BlendProperty6 best weights: {'w1': 0.019542980079988316, 'w2': 0.9785152705488447, 'w3': 0.0019417493711669787}
# 📉 Best MAPE: 0.0003
#
# 🔧 Optimizing ensemble weights for: BlendProperty7
# 📈 BlendProperty7 | Trial 100: MAPE = 0.8964
# 📈 BlendProperty7 | Trial 200: MAPE = 0.8968
# 📈 BlendProperty7 | Trial 300: MAPE = 0.8964
# 📈 BlendProperty7 | Trial 400: MAPE = 0.8953
# 📈 BlendProperty7 | Trial 500: MAPE = 0.8967
# 📈 BlendProperty7 | Trial 600: MAPE = 0.9154
# 📈 BlendProperty7 | Trial 800: MAPE = 0.8958
# 📈 BlendProperty7 | Trial 900: MAPE = 0.8957
# ✅ BlendProperty7 best weights: {'w1': 0.0006364918128472507, 'w2': 0.2736118432464211, 'w3': 0.7257516649407316}
# 📉 Best MAPE: 0.8953
#
# 🔧 Optimizing ensemble weights for: BlendProperty8
# 📈 BlendProperty8 | Trial 100: MAPE = 0.2334
# 📈 BlendProperty8 | Trial 200: MAPE = 0.2321
# 📈 BlendProperty8 | Trial 300: MAPE = 0.2325
# 📈 BlendProperty8 | Trial 400: MAPE = 0.2318
# 📈 BlendProperty8 | Trial 500: MAPE = 0.2319
# 📈 BlendProperty8 | Trial 700: MAPE = 0.2318
# 📈 BlendProperty8 | Trial 900: MAPE = 0.2333
# ✅ BlendProperty8 best weights: {'w1': 0.9983009744654799, 'w2': 0.0009393260956575873, 'w3': 0.0007596994388624727}
# 📉 Best MAPE: 0.2318
#
# 🔧 Optimizing ensemble weights for: BlendProperty9
# 📈 BlendProperty9 | Trial 100: MAPE = 0.4974
# 📈 BlendProperty9 | Trial 200: MAPE = 0.8180
# 📈 BlendProperty9 | Trial 300: MAPE = 0.4902
# 📈 BlendProperty9 | Trial 400: MAPE = 0.4861
# 📈 BlendProperty9 | Trial 600: MAPE = 0.4848
# 📈 BlendProperty9 | Trial 700: MAPE = 0.4963
# 📈 BlendProperty9 | Trial 800: MAPE = 0.5027
# 📈 BlendProperty9 | Trial 900: MAPE = 0.5035
# ✅ BlendProperty9 best weights: {'w1': 0.07462170641845464, 'w2': 0.1258215160900277, 'w3': 0.7995567774915177}
# 📉 Best MAPE: 0.4840
#
# 🔧 Optimizing ensemble weights for: BlendProperty10
# 📈 BlendProperty10 | Trial 100: MAPE = 0.0975
# 📈 BlendProperty10 | Trial 200: MAPE = 0.0968
# 📈 BlendProperty10 | Trial 300: MAPE = 0.0991
# 📈 BlendProperty10 | Trial 400: MAPE = 0.1020
# 📈 BlendProperty10 | Trial 500: MAPE = 0.1197
# 📈 BlendProperty10 | Trial 600: MAPE = 0.0974
# 📈 BlendProperty10 | Trial 700: MAPE = 0.0967
# 📈 BlendProperty10 | Trial 800: MAPE = 0.0967
# 📈 BlendProperty10 | Trial 900: MAPE = 0.0967
# ✅ BlendProperty10 best weights: {'w1': 0.00031837672731703515, 'w2': 1.0666792476037045e-05, 'w3': 0.9996709564802069}
# 📉 Best MAPE: 0.0967

# %%
# === Config ===
SAVE_PATH = "/pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models"
BASE_PATH = "/pscratch/sd/r/ritesh11/temp_dir/dataset"
MODEL_NAMES = ["LASSOCV", "RIDGECV", "ELASTICNETCV"]
TARGETS = [f"BlendProperty{i}" for i in range(1, 11)]
degree = 2

X = pd.read_csv("/pscratch/sd/r/ritesh11/temp_dir/dataset/train.csv")
tar = X.iloc[:,55:]
X = X.iloc[:,:55]

# %%
tar
# Out:
#       BlendProperty1  BlendProperty2  BlendProperty3  BlendProperty4  \
# 0           0.489143        0.607589        0.321670       -1.236055
# 1          -1.257481       -1.475283       -0.437385       -1.402911
# 2           1.784349        0.450467        0.622687        1.375614
# 3          -0.066422        0.483730       -1.865442       -0.046295
# 4          -0.118913       -1.172398        0.301785       -1.787407
# ...              ...             ...             ...             ...
# 1995       -0.028366       -0.327297       -0.316933       -1.294092
# 1996       -0.449245        0.156778       -0.367445       -0.938615
# 1997        0.029135        0.164890       -0.092942       -1.134490
# 1998       -0.232960       -0.464947        0.112536       -0.793522
# 1999       -1.797180       -1.312212       -0.511896       -1.450066
#
#       BlendProperty5  BlendProperty6  BlendProperty7  BlendProperty8  \
# 0           1.601132        1.384662        0.305850        0.193460
# 1           0.147941       -1.143244       -0.439171       -1.379041
# 2          -0.428790        1.161616        0.601289        0.872950
# 3          -0.163820       -0.209693       -1.840566        0.300293
# 4          -0.493361       -0.528049        0.286344       -0.265192
# ...              ...             ...             ...             ...
# 1995       -0.530259       -0.421526       -0.320869        0.709627
# 1996       -0.577451       -0.209996       -0.370505       -0.195531
# 1997       -0.437479       -0.695636       -0.101073        0.063650
# 1998       -0.811272       -1.194914        0.100644        0.760116
# 1999       -0.365154       -1.087937       -0.512119       -0.582473
#
#       BlendProperty9  BlendProperty10
# 0           0.580374        -0.762738
# 1          -1.280989        -0.503625
# 2           0.660000         2.024576
# 3          -0.351336        -1.551914
# 4           0.430513         0.735073
# ...              ...              ...
# 1995       -0.737244        -0.744289
# 1996       -0.032834         0.269718
# 1997        0.624368        -0.477053
# 1998       -0.751394        -0.857598
# 1999       -0.834879        -0.272462
#
# [2000 rows x 10 columns]

# %%
from sklearn.linear_model import Lasso, Ridge, ElasticNet

# %%
for target in TARGETS:
    print(f"\n🔄 Retraining on full data for: {target}")

    y = tar[[target]].values.ravel()

    for model_name in MODEL_NAMES:
        model_path = os.path.join("/pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs", f"{target}_{model_name}.joblib")
        if not os.path.exists(model_path):
            print(f"  ⚠️ Skipping {model_name} — model file not found.")
            continue

        print(f"  🔧 Loading model: {model_name}")

        # === Load trained model pipeline ===
        pipeline = joblib.load(model_path)

        # === Extract fitted regressor and its tuned params ===
        reg = pipeline.named_steps[model_name.lower()]
        if model_name == "LASSOCV":
            final_model = Lasso(alpha=reg.alpha_, max_iter=10000)
        elif model_name == "RIDGECV":
            final_model = Ridge(alpha=reg.alpha_)
        elif model_name == "ELASTICNETCV":
            final_model = ElasticNet(alpha=reg.alpha_, l1_ratio=reg.l1_ratio_, max_iter=10000)
        else:
            raise ValueError(f"Unknown model name: {model_name}")

        # === Rebuild pipeline and fit on full data ===
        full_model = make_pipeline(
            StandardScaler(),
            PolynomialFeatures(degree=degree),
            final_model
        )
        full_model.fit(X, y)

        # === Save retrained model ===
        full_model_path = os.path.join(SAVE_PATH, f"{target}_{model_name}_FULL.joblib")
        joblib.dump(full_model, full_model_path)
        print(f"  💾 Saved full-data model to: {full_model_path}")
# Out:
# 🔄 Retraining on full data for: BlendProperty1
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty1_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty1_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty1_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty2
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty2_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty2_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty2_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty3
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty3_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty3_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty3_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty4
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty4_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty4_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty4_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty5
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty5_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty5_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty5_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty6
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty6_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty6_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty6_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty7
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty7_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty7_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty7_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty8
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty8_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty8_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty8_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty9
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty9_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty9_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty9_ELASTICNETCV_FULL.joblib
#
# 🔄 Retraining on full data for: BlendProperty10
#   🔧 Loading model: LASSOCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty10_LASSOCV_FULL.joblib
#   🔧 Loading model: RIDGECV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty10_RIDGECV_FULL.joblib
#   🔧 Loading model: ELASTICNETCV
#   💾 Saved full-data model to: /pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models/BlendProperty10_ELASTICNETCV_FULL.joblib

# %%
SAVE_PATH = "/pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/final_LR_models"
ENSEMBLE_DIR = "/pscratch/sd/r/ritesh11/temp_dir/LR_model_outputs/optuna_ensemble"

MODEL_NAMES = ["LASSOCV", "RIDGECV", "ELASTICNETCV"]
TARGETS = [f"BlendProperty{i}" for i in range(1, 11)]

# %%
predictions = {"ID" : [i for i in range(1,501)]}
X_test = pd.read_csv("/pscratch/sd/r/ritesh11/temp_dir/dataset/test.csv")
X_test.drop(columns=["ID"], inplace=True)

# %%
for target in TARGETS:
    print(f"\n🔍 Building ensemble prediction for: {target}")

    # === Load ensemble weights ===
    weights_path = os.path.join(ENSEMBLE_DIR, f"{target}_weights.json")
    if not os.path.exists(weights_path):
        print(f"⚠️ Ensemble weights not found: {weights_path}")
        continue
    with open(weights_path, "r") as f:
        weights = json.load(f)

    # === Load models and compute weighted predictions ===
    preds = []
    for model_name in MODEL_NAMES:
        model_file = os.path.join(SAVE_PATH, f"{target}_{model_name}_FULL.joblib")
        if not os.path.exists(model_file):
            print(f"⚠️ Model not found: {model_file}")
            continue

        model = joblib.load(model_file)
        y_pred = model.predict(X_test)
        weight = weights.get(f"w{MODEL_NAMES.index(model_name) + 1}", 0.0)
        preds.append(weight * y_pred)

    # === Combine predictions ===
    if not preds:
        print(f"❌ No predictions generated for {target}")
        continue
    y_ensemble = np.sum(preds, axis=0)

    # === Save ensemble predictions ===
    predictions[target] = y_ensemble
# Out:
# 🔍 Building ensemble prediction for: BlendProperty1
#
# 🔍 Building ensemble prediction for: BlendProperty2
#
# 🔍 Building ensemble prediction for: BlendProperty3
#
# 🔍 Building ensemble prediction for: BlendProperty4
#
# 🔍 Building ensemble prediction for: BlendProperty5
#
# 🔍 Building ensemble prediction for: BlendProperty6
#
# 🔍 Building ensemble prediction for: BlendProperty7
#
# 🔍 Building ensemble prediction for: BlendProperty8
#
# 🔍 Building ensemble prediction for: BlendProperty9
#
# 🔍 Building ensemble prediction for: BlendProperty10

# %%
df = pd.DataFrame(predictions)
df.to_csv("LR_submission.csv",index=False)

# %%
def compute_volume_weighted_blend_features(X):
    """
    Computes volume-weighted blend-level properties for each of the 10 properties.
    """
    weighted_props = {}
    for prop_idx in range(1, 11):  # Property1 to Property10
        blend_prop = 0
        for comp_idx in range(1, 6):  # Component1 to Component5
            vol_col = f'Component{comp_idx}_fraction'
            prop_col = f'Component{comp_idx}_Property{prop_idx}'
            blend_prop += X[vol_col] * X[prop_col]
        weighted_props[f'BlendEst_Property{prop_idx}'] = blend_prop / 100.0
    return pd.DataFrame(weighted_props)

# %%
# Compute and append new blend-level features
blend_features = compute_volume_weighted_blend_features(X)
X = pd.concat([X, blend_features], axis=1)

# Do the same for test data
X_test = test_df[X.columns[:55]]  # assumes same structure
blend_features_test = compute_volume_weighted_blend_features(X_test)
X_test = pd.concat([X_test, blend_features_test], axis=1)

# %%
correlations = X.corrwith(y.iloc[:,0]).sort_values(key=abs, ascending=False)

# %%
corr_set = set(correlations.index.tolist()[:20])

# %%
fi_df = pd.read_csv("/pscratch/sd/r/ritesh11/temp_dir/feature_importance/BlendProperty1.csv")

# %%
fi_set = set(fi_df.iloc[:20,0].tolist())

# %%
corr_set
# Out:
# {'BlendEst_Property1',
#  'BlendEst_Property6',
#  'Component1_Property1',
#  'Component1_Property10',
#  'Component1_Property3',
#  'Component1_Property4',
#  'Component1_Property8',
#  'Component2_Property1',
#  'Component2_Property10',
#  'Component2_fraction',
#  'Component3_Property1',
#  'Component3_Property3',
#  'Component3_Property9',
#  'Component3_fraction',
#  'Component4_Property1',
#  'Component4_fraction',
#  'Component5_Property1',
#  'Component5_Property2',
#  'Component5_Property5',
#  'Component5_fraction'}

# %%
cols_to_keep = fi_set.intersection(corr_set)

# %%
cols_to_keep
# Out:
# {'BlendEst_Property1',
#  'Component1_Property1',
#  'Component2_Property1',
#  'Component2_fraction',
#  'Component3_Property1',
#  'Component3_Property9',
#  'Component3_fraction',
#  'Component4_Property1',
#  'Component4_fraction',
#  'Component5_Property1',
#  'Component5_fraction'}

# %%
def objective(trial, X, y):
    # -------- Feature Subset Selection --------
    # cols_to_remove = [col for col in cols_to_keep if trial.suggest_categorical(f"remove_{col}", [True, False])]
    # cols_to_add = [col for col in optional_cols if trial.suggest_categorical(f"add_{col}", [True, False])]
    
    # selected_cols = list(set(cols_to_keep) - set(cols_to_remove)) + cols_to_add
    # selected_cols = list(sorted(set(selected_cols)))  # deduplicate and sort

    # X_sel = X[selected_cols].copy()

    # -------- RBF Kernel Only --------
    length_scale = trial.suggest_float("length_scale", 0.1, 10.0, log=True)
    constant = trial.suggest_float("constant", 0.1, 100.0, log=True)
    alpha = trial.suggest_float("alpha", 1e-6, 1e-1, log=True)
    normalize_y = trial.suggest_categorical("normalize_y", [True, False])
    n_restarts_optimizer = trial.suggest_int("n_restarts_optimizer", 0, 3)

    kernel = C(constant, constant_value_bounds=(1e-2, 1e6)) * RBF(length_scale=length_scale, length_scale_bounds=(1e-2, 1e5))

    # -------- Build pipeline --------
    pipeline = Pipeline([
        ("scaler", MinMaxScaler()),
        ("gpr", GaussianProcessRegressor(
            kernel=kernel,
            alpha=alpha,
            normalize_y=normalize_y,
            n_restarts_optimizer=n_restarts_optimizer,
            random_state=42
        ))
    ])

    # -------- Cross-validation --------
    score = cross_val_score(
        pipeline, X, y,
        scoring=make_scorer(mean_absolute_percentage_error, greater_is_better=False),
        cv=3,
        n_jobs=-1
    )
    
    return -np.mean(score)

# %%
study = optuna.create_study(direction="minimize", sampler=TPESampler(seed=42))
study.enqueue_trial({
    "length_scale": 1.0,
    "constant": 1.0,
    "alpha": 0.01,
    "normalize_y": True,
    "n_restarts_optimizer": 0
})

study.optimize(lambda trial: objective(trial, X, y), n_trials=50)

print("Best trial:")
print(study.best_trial.params)
# Out:
# [I 2025-07-07 11:01:46,172] A new study created in memory with name: no-name-e2f7c17a-0787-4b86-bb8a-41ac51021572
# [I 2025-07-07 11:02:02,930] Trial 0 finished with value: 1.043538644229599 and parameters: {'length_scale': 1.0, 'constant': 1.0, 'alpha': 0.01, 'normalize_y': True, 'n_restarts_optimizer': 0}. Best is trial 0 with value: 1.043538644229599.
# [I 2025-07-07 11:02:16,282] Trial 1 finished with value: 1.0706228111502767 and parameters: {'length_scale': 0.5611516415334505, 'constant': 71.14476009343416, 'alpha': 0.004570563099801453, 'normalize_y': True, 'n_restarts_optimizer': 0}. Best is trial 0 with value: 1.043538644229599.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [I 2025-07-07 11:02:44,564] Trial 2 finished with value: 1.1117553880325055 and parameters: {'length_scale': 0.13066739238053282, 'constant': 39.67605077052987, 'alpha': 0.0010129197956845735, 'normalize_y': True, 'n_restarts_optimizer': 3}. Best is trial 0 with value: 1.043538644229599.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [I 2025-07-07 11:03:11,538] Trial 3 finished with value: 1.0 and parameters: {'length_scale': 4.622589001020832, 'constant': 0.4335281794951565, 'alpha': 8.111941985431925e-06, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 3 with value: 1.0.
# [I 2025-07-07 11:03:28,309] Trial 4 finished with value: 1.0966925000908863 and parameters: {'length_scale': 0.7309539835912913, 'constant': 0.7476312062252299, 'alpha': 0.0011462107403425038, 'normalize_y': False, 'n_restarts_optimizer': 1}. Best is trial 3 with value: 1.0.
# [I 2025-07-07 11:03:40,488] Trial 5 finished with value: 1.1057071375756427 and parameters: {'length_scale': 0.8168455894760165, 'constant': 22.673986523780385, 'alpha': 9.962513222055122e-06, 'normalize_y': False, 'n_restarts_optimizer': 0}. Best is trial 3 with value: 1.0.
# [I 2025-07-07 11:04:13,805] Trial 6 finished with value: 1.1057722905849137 and parameters: {'length_scale': 1.6409286730647923, 'constant': 0.32476735706274484, 'alpha': 2.114744796061573e-06, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 3 with value: 1.0.
# [I 2025-07-07 11:04:40,832] Trial 7 finished with value: 1.0850396776452318 and parameters: {'length_scale': 0.4066563313514795, 'constant': 0.1963434157293333, 'alpha': 0.002637333993381526, 'normalize_y': True, 'n_restarts_optimizer': 1}. Best is trial 3 with value: 1.0.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [I 2025-07-07 11:05:07,301] Trial 8 finished with value: 1.1117553880325055 and parameters: {'length_scale': 0.1171593739230706, 'constant': 53.45166110646818, 'alpha': 1.9674328025306114e-05, 'normalize_y': True, 'n_restarts_optimizer': 2}. Best is trial 3 with value: 1.0.
# [I 2025-07-07 11:05:46,572] Trial 9 finished with value: 0.938443956038825 and parameters: {'length_scale': 1.2399967836846095, 'constant': 0.35856126103453967, 'alpha': 0.07045683638454503, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 9 with value: 0.938443956038825.
# [I 2025-07-07 11:06:27,330] Trial 10 finished with value: 0.9384487132659123 and parameters: {'length_scale': 7.767353816237061, 'constant': 4.748459024928741, 'alpha': 0.07041830285016017, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 9 with value: 0.938443956038825.
# [I 2025-07-07 11:07:05,003] Trial 11 finished with value: 0.9383951666238808 and parameters: {'length_scale': 6.53626408296573, 'constant': 5.610906143906856, 'alpha': 0.08570570220432928, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 11 with value: 0.9383951666238808.
# [I 2025-07-07 11:07:40,017] Trial 12 finished with value: 0.9380775141175034 and parameters: {'length_scale': 2.733762389478874, 'constant': 4.737772386034826, 'alpha': 0.07424873426630181, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:08:06,145] Trial 13 finished with value: 1.1048936518767258 and parameters: {'length_scale': 3.0710531529881644, 'constant': 5.855228983440085, 'alpha': 0.00010786728257746637, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:08:44,966] Trial 14 finished with value: 1.025501184322275 and parameters: {'length_scale': 9.070334999179927, 'constant': 11.711426667473567, 'alpha': 0.014349454217728784, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:09:03,827] Trial 15 finished with value: 0.942808067179519 and parameters: {'length_scale': 3.07408921582859, 'constant': 1.6383495194436424, 'alpha': 0.09551743658898718, 'normalize_y': False, 'n_restarts_optimizer': 1}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:09:33,494] Trial 16 finished with value: 1.1042674380900193 and parameters: {'length_scale': 4.446628727033125, 'constant': 2.3934273433878355, 'alpha': 0.0001863626384031077, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:10:05,967] Trial 17 finished with value: 1.008242282409773 and parameters: {'length_scale': 2.0227468316415007, 'constant': 15.47050493207913, 'alpha': 0.01957152611972286, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:10:51,427] Trial 18 finished with value: 0.9723663578483208 and parameters: {'length_scale': 5.554351453873709, 'constant': 7.067480879460604, 'alpha': 0.03273896956419002, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:11:12,554] Trial 19 finished with value: 1.1012381685379469 and parameters: {'length_scale': 2.283124048974706, 'constant': 1.6165903076589325, 'alpha': 0.0005705702435749432, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:11:33,678] Trial 20 finished with value: 1.058000960000173 and parameters: {'length_scale': 0.3418278977925777, 'constant': 3.0717104594057867, 'alpha': 0.006387112930574299, 'normalize_y': False, 'n_restarts_optimizer': 1}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:12:17,419] Trial 21 finished with value: 0.9418324683997276 and parameters: {'length_scale': 1.9008022288222557, 'constant': 0.1206611819804921, 'alpha': 0.09415127191518181, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:12:55,101] Trial 22 finished with value: 0.9747147916732275 and parameters: {'length_scale': 1.309949119346941, 'constant': 9.487381079187598, 'alpha': 0.03165593117729593, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:660: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL: .
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# [I 2025-07-07 11:13:43,463] Trial 23 finished with value: 0.9631464452534534 and parameters: {'length_scale': 3.293769882368276, 'constant': 3.774830505959622, 'alpha': 0.0376537228924578, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:14:18,378] Trial 24 finished with value: 1.0810198559823494 and parameters: {'length_scale': 6.645092074214109, 'constant': 24.515235346094418, 'alpha': 0.0031397350757917655, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:14:55,064] Trial 25 finished with value: 1.0375328108720765 and parameters: {'length_scale': 1.3395945245650809, 'constant': 0.8527284987366477, 'alpha': 0.01117548927359846, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:15:31,827] Trial 26 finished with value: 0.977943733199119 and parameters: {'length_scale': 3.821849531339669, 'constant': 1.9300839230496118, 'alpha': 0.031009255120950024, 'normalize_y': True, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:16:08,263] Trial 27 finished with value: 0.9438944267760435 and parameters: {'length_scale': 2.4954821936429985, 'constant': 0.4905300632698849, 'alpha': 0.05451352447965895, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [I 2025-07-07 11:16:39,307] Trial 28 finished with value: 1.0 and parameters: {'length_scale': 6.808422071980575, 'constant': 0.10195815533783562, 'alpha': 4.676116094442294e-05, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:17:13,003] Trial 29 finished with value: 1.0442276635239347 and parameters: {'length_scale': 1.2402836529060248, 'constant': 1.2323828392211704, 'alpha': 0.009814373888610952, 'normalize_y': True, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:17:38,300] Trial 30 finished with value: 1.0899926161938789 and parameters: {'length_scale': 0.21216907439465535, 'constant': 8.923876621788732, 'alpha': 0.001998056078116503, 'normalize_y': False, 'n_restarts_optimizer': 1}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:18:19,712] Trial 31 finished with value: 0.9430441907820694 and parameters: {'length_scale': 7.715859163432508, 'constant': 5.128076318263838, 'alpha': 0.0958032547699763, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:18:56,386] Trial 32 finished with value: 0.9469333736112296 and parameters: {'length_scale': 9.33148393033662, 'constant': 4.227895651150217, 'alpha': 0.05060764215711841, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:19:36,167] Trial 33 finished with value: 1.0536428371694275 and parameters: {'length_scale': 6.192602961985359, 'constant': 17.11871567155988, 'alpha': 0.007165307310646598, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:19:43,863] Trial 34 finished with value: 1.0190874992072236 and parameters: {'length_scale': 4.966492240370624, 'constant': 2.444038629372727, 'alpha': 0.017041619797822097, 'normalize_y': True, 'n_restarts_optimizer': 0}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:20:21,993] Trial 35 finished with value: 0.9418834577358073 and parameters: {'length_scale': 0.9242781775541906, 'constant': 3.288599772107027, 'alpha': 0.05844017237695785, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:20:56,558] Trial 36 finished with value: 1.0025233506961195 and parameters: {'length_scale': 0.6504695255012672, 'constant': 6.663691649529972, 'alpha': 0.021311008674193478, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:21:45,685] Trial 37 finished with value: 1.0706043174801076 and parameters: {'length_scale': 4.528661583224634, 'constant': 32.01950996780789, 'alpha': 0.0045301542527165315, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [I 2025-07-07 11:22:24,647] Trial 38 finished with value: 1.1117553880325055 and parameters: {'length_scale': 9.879913672359567, 'constant': 0.6639244354452427, 'alpha': 1.2733977653242122e-06, 'normalize_y': True, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:22:56,168] Trial 39 finished with value: 1.0980786376132246 and parameters: {'length_scale': 1.6519214307773071, 'constant': 1.2248662736976483, 'alpha': 0.0009705909949817861, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:23:06,312] Trial 40 finished with value: 0.9383441832654534 and parameters: {'length_scale': 0.4706328389282425, 'constant': 85.0140046956817, 'alpha': 0.08544921879575802, 'normalize_y': False, 'n_restarts_optimizer': 0}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:23:15,160] Trial 41 finished with value: 0.9427032556719674 and parameters: {'length_scale': 0.38181955469926215, 'constant': 0.2825218670900886, 'alpha': 0.056710710091017975, 'normalize_y': False, 'n_restarts_optimizer': 0}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:23:27,133] Trial 42 finished with value: 0.9939866442128956 and parameters: {'length_scale': 0.5237592762091884, 'constant': 65.87974747718778, 'alpha': 0.024075674288646064, 'normalize_y': False, 'n_restarts_optimizer': 0}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:23:45,357] Trial 43 finished with value: 0.9999999975935102 and parameters: {'length_scale': 0.22103623954678486, 'constant': 42.066569581857486, 'alpha': 0.09559580179746453, 'normalize_y': False, 'n_restarts_optimizer': 1}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:23:57,895] Trial 44 finished with value: 0.9457001494274752 and parameters: {'length_scale': 0.5035098959864246, 'constant': 10.757677974630832, 'alpha': 0.05204001904691423, 'normalize_y': False, 'n_restarts_optimizer': 0}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:24:20,051] Trial 45 finished with value: 1.016796034095109 and parameters: {'length_scale': 1.0462413240996473, 'constant': 16.38620145146127, 'alpha': 0.017018500471462777, 'normalize_y': False, 'n_restarts_optimizer': 1}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:24:51,764] Trial 46 finished with value: 0.9403448511815115 and parameters: {'length_scale': 3.8060082227804615, 'constant': 5.0506312243491385, 'alpha': 0.06469029248710913, 'normalize_y': True, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [I 2025-07-07 11:25:23,540] Trial 47 finished with value: 1.1560218268172202 and parameters: {'length_scale': 2.7051068147860247, 'constant': 0.16372814993256185, 'alpha': 5.180153663431496e-06, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:26:00,240] Trial 48 finished with value: 1.0439345917879959 and parameters: {'length_scale': 0.6630506658035206, 'constant': 72.52838226546183, 'alpha': 0.009528648773409162, 'normalize_y': False, 'n_restarts_optimizer': 2}. Best is trial 12 with value: 0.9380775141175034.
# [I 2025-07-07 11:26:42,882] Trial 49 finished with value: 0.9601535540428981 and parameters: {'length_scale': 0.2835114048085198, 'constant': 2.486382976448723, 'alpha': 0.039608611854460476, 'normalize_y': False, 'n_restarts_optimizer': 3}. Best is trial 12 with value: 0.9380775141175034.
# Best trial:
# {'length_scale': 2.733762389478874, 'constant': 4.737772386034826, 'alpha': 0.07424873426630181, 'normalize_y': False, 'n_restarts_optimizer': 2}
