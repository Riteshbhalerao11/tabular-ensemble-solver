# %%
import pandas as pd
import numpy as np
from autogluon.tabular import TabularPredictor
import os

# %%
def compute_volume_weighted_component_features(X):
    """
    Computes individual volume-weighted features WjPk = Componentj_fraction * Componentj_Propertyk
    for j in 1..5 and k in 1..10 (total 50 features).
    """
    features = {}
    for comp_idx in range(1, 6):  # Components 1–5
        for prop_idx in range(1, 11):  # Properties 1–10
            vol_col = f'Component{comp_idx}_fraction'
            prop_col = f'Component{comp_idx}_Property{prop_idx}'
            feat_name = f'W{comp_idx}P{prop_idx}'
            features[feat_name] = X[vol_col] * X[prop_col]
    return pd.DataFrame(features)

# %%
targets = [f"BlendProperty{i}" for i in [3,5,7,8,9,10]]
BASE_PATH = "/pscratch/sd/r/ritesh11/temp_dir/dataset"
model_dir = "/pscratch/sd/r/ritesh11/temp_dir/autogluon_models"
fi_path = "/pscratch/sd/r/ritesh11/temp_dir/feature_importance"

# %%
for t in targets:
    X_train = pd.read_csv(f"{BASE_PATH}/train/{t}_X.csv")
    y_train = pd.read_csv(f"{BASE_PATH}/train/{t}_y.csv")
    X_val = pd.read_csv(f"{BASE_PATH}/val/{t}_X.csv")
    y_val = pd.read_csv(f"{BASE_PATH}/val/{t}_y.csv")

    df = pd.read_csv(os.path.join(fi_path, f"{t}.csv"))
    cols = df[df["importance"] > 0.1].iloc[:, 0].tolist()

    blend_features = compute_volume_weighted_component_features(X_train)
    X_train = pd.concat([X_train, blend_features], axis=1)
    blend_features = compute_volume_weighted_component_features(X_val)
    X_val = pd.concat([X_val, blend_features], axis=1)
    
    X_train = X_train[cols]
    X_val = X_val[cols]
    
    predictor = TabularPredictor(
        label=t,
        problem_type="regression",
        eval_metric="mean_absolute_percentage_error",  # You can use "rmse", "r2", etc.
        path=os.path.join(model_dir,t),
    )

    predictor.fit(
        train_data=pd.concat([X_train,y_train],axis=1),
        tuning_data=pd.concat([X_val,y_val],axis=1),
        excluded_model_types = ['KNN'],
        dynamic_stacking=False,
        auto_stack=True,
        time_limit=6000,
        presets='best_quality',
        use_bag_holdout = True,
        # fit_strategy='parallel',
        hyperparameters = 'zeroshot',
        num_gpus=1,
        keep_only_best=True,
    )
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.12.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Mar 13 20:09:44 UTC 2025 (330b47d)
# CPU Count:          256
# Memory Avail:       191.07 GB / 502.97 GB (38.0%)
# Disk Space Avail:   15421725.24 GB / 45921523.47 GB (33.6%)
# ===================================================
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/autogluon/common/utils/utils.py:97: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Beginning AutoGluon training ... Time limit = 6000s
# AutoGluon will save models to "/pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3"
# Train Data Rows:    1900
# Train Data Columns: 13
# Tuning Data Rows:    100
# Tuning Data Columns: 13
# Label Column:       BlendProperty3
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    195657.43 MB
# 	Train Data (Original)  Memory Usage: 0.20 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Component2_fraction', 'Component4_fraction', 'Component5_fraction', 'W1P7', 'Component3_fraction', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['Component2_fraction', 'Component4_fraction', 'Component5_fraction', 'W1P7', 'Component3_fraction', ...]
# 	0.0s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.20 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.03s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_percentage_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# use_bag_holdout=True, will use tuning_data as holdout (will not be used for early stopping).
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3998.98s of the 5999.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	-1.0312	 = Validation score   (-mean_absolute_percentage_error)
# 	24.42s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3950.64s of the 5951.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	-1.3256	 = Validation score   (-mean_absolute_percentage_error)
# 	17.36s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 3930.72s of the 5931.70s of remaining time.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	-2.4879	 = Validation score   (-mean_absolute_percentage_error)
# 	0.57s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3929.79s of the 5930.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.20%)
# 	-0.9005	 = Validation score   (-mean_absolute_percentage_error)
# 	320.54s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 3606.97s of the 5607.96s of remaining time.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	-1.8191	 = Validation score   (-mean_absolute_percentage_error)
# 	0.48s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3606.00s of the 5606.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.5888	 = Validation score   (-mean_absolute_percentage_error)
# 	161.92s	 = Training   runtime
# 	3.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 3438.86s of the 5439.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-1.4484	 = Validation score   (-mean_absolute_percentage_error)
# 	14.82s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3421.61s of the 5422.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.3226	 = Validation score   (-mean_absolute_percentage_error)
# 	382.6s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 3036.93s of the 5037.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.01%)
# 	-1.4294	 = Validation score   (-mean_absolute_percentage_error)
# 	31.8s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 3002.51s of the 5003.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.20%)
# 	-0.9611	 = Validation score   (-mean_absolute_percentage_error)
# 	241.65s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 2758.69s of the 4759.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.5877	 = Validation score   (-mean_absolute_percentage_error)
# 	381.97s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 2374.64s of the 4375.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.01%)
# 	-1.5033	 = Validation score   (-mean_absolute_percentage_error)
# 	36.26s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 2335.57s of the 4336.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.7488	 = Validation score   (-mean_absolute_percentage_error)
# 	83.82s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 2249.60s of the 4250.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.20%)
# 	-1.0177	 = Validation score   (-mean_absolute_percentage_error)
# 	1272.19s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 974.67s of the 2975.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	-1.193	 = Validation score   (-mean_absolute_percentage_error)
# 	13.09s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 958.90s of the 2959.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.2621	 = Validation score   (-mean_absolute_percentage_error)
# 	517.82s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 439.11s of the 2440.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.02%)
# 	-1.314	 = Validation score   (-mean_absolute_percentage_error)
# 	22.02s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 414.92s of the 2415.90s of remaining time.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	-1.5698	 = Validation score   (-mean_absolute_percentage_error)
# 	0.52s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 414.05s of the 2415.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.19%)
# 	-1.1546	 = Validation score   (-mean_absolute_percentage_error)
# 	250.3s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 161.61s of the 2162.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.9706	 = Validation score   (-mean_absolute_percentage_error)
# 	145.75s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 13.64s of the 2014.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.20%)
# 	-1.742	 = Validation score   (-mean_absolute_percentage_error)
# 	17.15s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 399.90s of the 1995.09s of remaining time.
# 	Ensemble Weights: {'NeuralNetTorch_r22_BAG_L1': 1.0}
# 	-0.2621	 = Validation score   (-mean_absolute_percentage_error)
# 	0.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1995.02s of the 1994.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.01%)
# 	-0.3034	 = Validation score   (-mean_absolute_percentage_error)
# 	11.53s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1981.11s of the 1981.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.01%)
# 	-0.2674	 = Validation score   (-mean_absolute_percentage_error)
# 	8.05s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1970.64s of the 1970.58s of remaining time.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	-0.3393	 = Validation score   (-mean_absolute_percentage_error)
# 	0.63s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1969.57s of the 1969.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.20%)
# 	-0.3133	 = Validation score   (-mean_absolute_percentage_error)
# 	68.89s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1898.56s of the 1898.50s of remaining time.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	-0.3662	 = Validation score   (-mean_absolute_percentage_error)
# 	0.54s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1897.66s of the 1897.60s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.4954	 = Validation score   (-mean_absolute_percentage_error)
# 	66.3s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1829.27s of the 1829.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.01%)
# 	-0.3096	 = Validation score   (-mean_absolute_percentage_error)
# 	14.96s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1812.18s of the 1812.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.2459	 = Validation score   (-mean_absolute_percentage_error)
# 	358.17s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 1451.95s of the 1451.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.02%)
# 	-0.355	 = Validation score   (-mean_absolute_percentage_error)
# 	32.77s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 1416.71s of the 1416.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.20%)
# 	-0.3537	 = Validation score   (-mean_absolute_percentage_error)
# 	54.06s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 1360.60s of the 1360.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.3014	 = Validation score   (-mean_absolute_percentage_error)
# 	260.45s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 1098.11s of the 1098.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.01%)
# 	-0.342	 = Validation score   (-mean_absolute_percentage_error)
# 	24.93s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 1070.02s of the 1069.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.384	 = Validation score   (-mean_absolute_percentage_error)
# 	228.17s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 839.65s of the 839.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.22%)
# 	-0.2416	 = Validation score   (-mean_absolute_percentage_error)
# 	331.26s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 506.17s of the 506.10s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	-0.4315	 = Validation score   (-mean_absolute_percentage_error)
# 	23.85s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 479.53s of the 479.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.3321	 = Validation score   (-mean_absolute_percentage_error)
# 	239.39s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 238.13s of the 238.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.05%)
# 	-0.3846	 = Validation score   (-mean_absolute_percentage_error)
# 	30.5s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 205.41s of the 205.35s of remaining time.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	-0.382	 = Validation score   (-mean_absolute_percentage_error)
# 	0.5s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 204.52s of the 204.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.19%)
# 	-0.4092	 = Validation score   (-mean_absolute_percentage_error)
# 	61.53s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 140.95s of the 140.89s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.6525	 = Validation score   (-mean_absolute_percentage_error)
# 	131.95s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 6.46s of remaining time.
# 	Ensemble Weights: {'CatBoost_r9_BAG_L2': 0.565, 'NeuralNetTorch_BAG_L2': 0.435}
# 	-0.2394	 = Validation score   (-mean_absolute_percentage_error)
# 	0.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 5993.62s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 19.0 rows/s (100 batch size)
# Deleting model LightGBM_BAG_L1. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/LightGBM_BAG_L1 will be removed.
# Deleting model LightGBMLarge_BAG_L1. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/LightGBMLarge_BAG_L1 will be removed.
# Deleting model NeuralNetTorch_r79_BAG_L1. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/NeuralNetTorch_r79_BAG_L1 will be removed.
# Deleting model LightGBM_r131_BAG_L1. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/LightGBM_r131_BAG_L1 will be removed.
# Deleting model CatBoost_r9_BAG_L1. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/CatBoost_r9_BAG_L1 will be removed.
# Deleting model CatBoost_r137_BAG_L1. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/CatBoost_r137_BAG_L1 will be removed.
# Deleting model NeuralNetFastAI_r102_BAG_L1. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/NeuralNetFastAI_r102_BAG_L1 will be removed.
# Deleting model CatBoost_r13_BAG_L1. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/CatBoost_r13_BAG_L1 will be removed.
# Deleting model WeightedEnsemble_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/WeightedEnsemble_L2 will be removed.
# Deleting model LightGBMXT_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/LightGBMXT_BAG_L2 will be removed.
# Deleting model LightGBM_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/LightGBM_BAG_L2 will be removed.
# Deleting model RandomForestMSE_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/RandomForestMSE_BAG_L2 will be removed.
# Deleting model CatBoost_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/CatBoost_BAG_L2 will be removed.
# Deleting model ExtraTreesMSE_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/ExtraTreesMSE_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/NeuralNetFastAI_BAG_L2 will be removed.
# Deleting model XGBoost_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/XGBoost_BAG_L2 will be removed.
# Deleting model LightGBMLarge_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/LightGBMLarge_BAG_L2 will be removed.
# Deleting model CatBoost_r177_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/CatBoost_r177_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r79_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/NeuralNetTorch_r79_BAG_L2 will be removed.
# Deleting model LightGBM_r131_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/LightGBM_r131_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r191_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/NeuralNetFastAI_r191_BAG_L2 will be removed.
# Deleting model LightGBM_r96_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/LightGBM_r96_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_r22_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/NeuralNetTorch_r22_BAG_L2 will be removed.
# Deleting model XGBoost_r33_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/XGBoost_r33_BAG_L2 will be removed.
# Deleting model ExtraTrees_r42_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/ExtraTrees_r42_BAG_L2 will be removed.
# Deleting model CatBoost_r137_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/CatBoost_r137_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_r102_BAG_L2. All files under /pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3/models/NeuralNetFastAI_r102_BAG_L2 will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty3")
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.12.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Mar 13 20:09:44 UTC 2025 (330b47d)
# CPU Count:          256
# Memory Avail:       196.68 GB / 502.97 GB (39.1%)
# Disk Space Avail:   15176948.96 GB / 45921523.47 GB (33.0%)
# ===================================================
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 6000s
# AutoGluon will save models to "/pscratch/sd/r/ritesh11/temp_dir/autogluon_models/BlendProperty5"
# Train Data Rows:    1900
# Train Data Columns: 5
# Tuning Data Rows:    100
# Tuning Data Columns: 5
# Label Column:       BlendProperty5
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    201384.50 MB
# 	Train Data (Original)  Memory Usage: 0.08 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 5 | ['Component2_Property5', 'Component2_fraction', 'W2P5', 'Component1_Property5', 'W1P5']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 5 | ['Component2_Property5', 'Component2_fraction', 'W2P5', 'Component1_Property5', 'W1P5']
# 	0.0s = Fit runtime
# 	5 features in original data used to generate 5 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.08 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.03s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_percentage_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# use_bag_holdout=True, will use tuning_data as holdout (will not be used for early stopping).
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3998.98s of the 5999.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	-0.1652	 = Validation score   (-mean_absolute_percentage_error)
# 	12.62s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3983.90s of the 5984.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=32, gpus=0, memory=0.00%)
# 	-0.0957	 = Validation score   (-mean_absolute_percentage_error)
# 	5.62s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 3976.01s of the 5976.99s of remaining time.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	-0.0646	 = Validation score   (-mean_absolute_percentage_error)
# 	0.47s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3975.18s of the 5976.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.19%)
# 	-0.1248	 = Validation score   (-mean_absolute_percentage_error)
# 	21.88s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 3951.28s of the 5952.27s of remaining time.
# /global/homes/r/ritesh11/.conda/envs/myenv_3.12/lib/python3.12/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	-0.0869	 = Validation score   (-mean_absolute_percentage_error)
# 	0.44s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 3950.50s of the 5951.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.2049	 = Validation score   (-mean_absolute_percentage_error)
# 	104.45s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 3843.94s of the 5844.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=128, gpus=0, memory=0.00%)
# 	-0.0732	 = Validation score   (-mean_absolute_percentage_error)
# 	11.42s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 3830.47s of the 5831.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=128, gpus=0, memory=0.00%)
